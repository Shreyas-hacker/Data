# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %%
google = pd.read_csv('C:/Users/Shreyas/GOOG.csv')

# %%
google
# Out:
#            Date         Open         High          Low        Close  \
# 0    2004-08-01    49.813286    56.528118    47.800831    50.993862
# 1    2004-09-01    51.158245    67.257904    49.285267    64.558022
# 2    2004-10-01    65.155777    99.601669    64.209328    94.964050
# 3    2004-11-01    96.413620   100.423584    80.353813    90.650223
# 4    2004-12-01    90.635277    99.566803    83.920448    96.035034
# ..          ...          ...          ...          ...          ...
# 192  2020-08-01  1486.640015  1659.219971  1458.650024  1634.180054
# 193  2020-09-01  1636.630005  1733.180054  1406.550049  1469.599976
# 194  2020-10-01  1484.270020  1687.000000  1436.000000  1621.010010
# 195  2020-11-01  1628.160034  1818.060059  1616.030029  1793.189941
# 196  2020-11-27  1773.089966  1803.869995  1772.439941  1793.189941
#
#        Adj Close     Volume
# 0      50.993862  134241100
# 1      64.558022  213503200
# 2      94.964050  516060900
# 3      90.650223  557267200
# ...

# %%
google.describe(include = 'all')
# Out:
#               Date         Open         High          Low        Close  \
# count          197   197.000000   197.000000   197.000000   197.000000
# unique         197          NaN          NaN          NaN          NaN
# top     2017-09-01          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN   543.224213   579.091114   517.410513   552.242978
# std            NaN   402.019275   429.208104   385.959565   410.620583
# min            NaN    49.813286    56.528118    47.800831    50.993862
# 25%            NaN   238.486099   254.376541   225.405121   241.499802
# 50%            NaN   349.808838   372.224823   333.599579   352.179932
# 75%            NaN   774.250000   804.380005   761.090027   777.289978
# max            NaN  1773.089966  1818.060059  1772.439941  1793.189941
#
#           Adj Close        Volume
# count    197.000000  1.970000e+02
# unique          NaN           NaN
# ...

# %%
google.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
Stocks = google.groupby('Date')['Open'].sum() #Makes Date the index and sums everything tgt
Stocks1 = google.groupby('Date')['High'].sum()
Stocks2 = google.groupby('Date')['Low'].sum()
Stocks3 = google.groupby('Date')['Close'].sum()
Stocks4 = google.groupby('Date')['Adj Close'].sum()
Stocks5 = google.groupby('Date')['Volume'].sum()

# %%
Stocks.index = pd.to_datetime(Stocks.index)
year = Stocks.index.to_period('Y')
year =year.to_timestamp() # makes the dates into year timestamps

# %%
Data = pd.DataFrame(Stocks)
Data1 = pd.DataFrame(Stocks1)
Data2 = pd.DataFrame(Stocks2)
Data3 = pd.DataFrame(Stocks3)
Data4 = pd.DataFrame(Stocks4)
Data5 = pd.DataFrame(Stocks5)

# %%
A=Data.set_index(year)
B=Data1.set_index(year)
C=Data2.set_index(year)
D=Data3.set_index(year)
E=Data4.set_index(year)
F=Data5.set_index(year)

# %%
Open = A.groupby('Date')['Open'].sum()
High = B.groupby('Date')['High'].sum()
Low = C.groupby('Date')['Low'].sum()
Close = D.groupby('Date')['Close'].sum()
AdjClose = E.groupby('Date')['Adj Close'].sum()
Volume = F.groupby('Date')['Volume'].sum()

# %%
Open = pd.DataFrame(Open)
High = pd.DataFrame(High)
Low = pd.DataFrame(Low)
Close = pd.DataFrame(Close)
AdjClose = pd.DataFrame(AdjClose)
Volume = pd.DataFrame(Volume)

# %%
plt.figure(figsize = (25,35))
plt.suptitle('Google Historical Data from 2004 to 2020')

plt.subplot(311)
plt.plot(Open,'bo')
plt.title('Google Open')
plt.xlabel('Date')
plt.ylabel('Open')
plt.grid(True, color = 'k')

plt.subplot(312)
plt.plot(High,'bo')
plt.title('Google High')
plt.xlabel('Date')
plt.ylabel('High')
plt.grid(True, color = 'k')

plt.subplot(313)
plt.plot(Low,'bo')
plt.title('Google Low')
plt.xlabel('Date')
plt.ylabel('Low')
plt.grid(True, color = 'k')

# %%
plt.figure(figsize = (25,35))
plt.suptitle('Google Historical Data from 2004 to 2020')

plt.subplot(311)
plt.plot(Close,'bo')
plt.title('Google Close')
plt.xlabel('Date')
plt.ylabel('Close')
plt.grid(True, color = 'k')

plt.subplot(312)
plt.plot(AdjClose,'bo')
plt.title('Google Adj Close')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.grid(True, color = 'k')

plt.subplot(313)
plt.plot(Volume,'bo')
plt.title('Google Volume')
plt.xlabel('Date')
plt.ylabel('Volume in 100000')
plt.grid(True, color = 'k')
